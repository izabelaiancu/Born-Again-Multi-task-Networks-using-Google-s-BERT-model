# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

# %%
# !git clone https://gist.github.com/60c2bdb54d156a41194446737ce03e2e.git
# Out:
# Cloning into '60c2bdb54d156a41194446737ce03e2e'...
# remote: Enumerating objects: 21, done.
# remote: Total 21 (delta 0), reused 0 (delta 0), pack-reused 21
# Unpacking objects: 100% (21/21), done.

# %%
# !mv 'configure (1).py' 'configure.py'

# %%
# !python download_glue_data.py
# Out:
# ...
# 	Completed!
# ...
# 	Completed!
# Processing MRPC...
# Local MRPC data not specified, downloading data from https://dl.fbaipublicfiles.com/senteval/senteval_data/msr_paraphrase_train.txt
# 	Completed!
# ...
# 	Completed!
# ...
# 	Completed!
# ...
# 	Completed!
# ...
# 	Completed!
# ...
# 	Completed!
# ...
# 	Completed!
# ...
# 	Completed!
# ...
# 	Completed!

# %%
# !mv CoLA cola && mv MNLI mnli && mv MRPC mrpc && mv QNLI qnli && mv QQP qqp && mv RTE rte && mv SST-2 sst && mv STS-B sts && mv diagnostic/diagnostic.tsv mnli && mkdir -p $BAM_DIR/glue_data && mv * $BAM_DIR/glue_data
# Out:
# mv: cannot stat 'CoLA': No such file or directory

# %%
# !mv "~/glue_data" "/content/drive/My_Drive/BAM_DIR/glue_data/"
# Out:
# mv: cannot stat '~/glue_data': No such file or directory

# %%
# !mv CoLA cola && mv MNLI mnli && mv MRPC mrpc && mv QNLI qnli && mv QQP qqp && mv RTE rte && mv SST-2 sst && mv STS-B sts && mv diagnostic/diagnostic.tsv mnli && mkdir -p $BAM_DIR/glue_data && mv * $BAM_DIR/glue_data

# %%
# !mkdir -p /content/drive/My Drive/BAM_DIR/gluedata
# Out:
# mkdir: cannot create directory ‘/content/drive/My’: Operation not supported

# %%
# %cd /content/drive/My Drive/BAM_DIR
# Out:
# /content/drive/My Drive/BAM_DIR

# %%
# !git clone "https://github.com/google-research/google-research/tree/master/bam"
# Out:
# Cloning into 'bam'...
# fatal: repository 'https://github.com/google-research/google-research/tree/master/bam/' not found

# %%
# !python -m bam.run_classifier debug-model /content/drive/My Drive/BAM_DIR '{"debug": true}'
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0801 17:30:26.179556 140700397815680 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0801 17:30:29.645133 140700397815680 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0801 17:30:33.806385 140700397815680 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0801 17:30:33.807468 140700397815680 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Traceback (most recent call last):
# ...

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier mrpc-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["mrpc"]}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0806 04:12:23.701149 140438914029440 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0806 04:12:27.498744 140438914029440 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0806 04:12:32.081588 140438914029440 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0806 04:12:32.082497 140438914029440 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier rte-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["rte"],"distill": false}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0801 18:04:23.414915 140666419218304 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0801 18:04:23.426456 140666419218304 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0801 18:04:23.554609 140666419218304 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0801 18:04:23.555951 140666419218304 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
# !ls
# !mv "My Drive" "Drive"
# Out:
# 'My Drive'
# mv: cannot move 'My Drive' to 'Drive': No such file or directory

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier rte-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["rte"],"distill":"True"}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# /usr/bin/python3: Error while finding module specification for 'bam.run_classifier' (ModuleNotFoundError: No module named 'bam')
# --- 3.249880313873291 seconds ---

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier mrpc-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["mrpc"],"train_batch_size": 128}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# /usr/bin/python3: Error while finding module specification for 'bam.run_classifier' (ModuleNotFoundError: No module named 'bam')
# --- 3.2780656814575195 seconds ---

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier rte-mrpc-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["rte", "mrpc"]}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0801 18:27:24.205475 140429029889920 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0801 18:27:24.217727 140429029889920 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0801 18:27:24.353483 140429029889920 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0801 18:27:24.354370 140429029889920 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier rte-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["rte"],"distill": true,"teachers": {"rte": "rte-model"}}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0806 14:46:30.030615 140659878963072 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0806 14:46:30.046039 140659878963072 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0806 14:46:30.195535 140659878963072 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0806 14:46:30.196587 140659878963072 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
# %cd /content/drive/My Drive/BAM_DIR
import time
start_time = time.time()
# !python -m bam.run_classifier rte-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["rte"]}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# /content/drive/My Drive/BAM_DIR
# WARNING: Logging before flag parsing goes to stderr.
# W0806 14:38:10.601285 139784760342400 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0806 14:38:16.705202 139784760342400 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0806 14:38:20.923077 139784760342400 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0806 14:38:20.923930 139784760342400 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier mrpc-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["mrpc"],"distill": true,"teachers": {"mrpc": "mrpc-model"}}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0802 06:00:36.232053 139755876390784 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0802 06:00:36.243584 139755876390784 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0802 06:00:36.364014 139755876390784 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0802 06:00:36.364832 139755876390784 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier rte-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["rte"],"distill": true,"teachers": {"rte": "rte-model"}}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0802 06:46:06.391116 139850100377472 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0802 06:46:06.401406 139850100377472 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0802 06:46:06.485614 139850100377472 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0802 06:46:06.486784 139850100377472 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
# !mv 'configure (1).py' 'configure.py'

# %%
# %cd ..
# Out:
# /content/drive/My Drive/BAM_DIR

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier mrpc-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["mrpc"],"distill": true,"train_batch_size": 64, "learning_rate": 5e-5,"teachers": {"mrpc": "mrpc-model"}}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0802 07:07:43.081529 139950558033792 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0802 07:07:43.094184 139950558033792 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0802 07:07:43.197657 139950558033792 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0802 07:07:43.198701 139950558033792 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier mrpc-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["mrpc"],"distill": true,"teachers": {"mrpc": "mrpc-model"}}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0802 07:33:27.575337 139735291832192 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0802 07:33:27.587716 139735291832192 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0802 07:33:27.673141 139735291832192 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0802 07:33:27.674206 139735291832192 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier mrpc-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["mrpc"], "distill": true, "teachers":{"mrpc": "mrpc-model"}}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0806 10:34:46.976403 140408772044672 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0806 10:34:46.991325 140408772044672 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0806 10:34:47.092641 140408772044672 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0806 10:34:47.093866 140408772044672 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd ..
# Out:
# /content/drive/My Drive/BAM_DIR

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier mrpc-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["mrpc"]}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0806 09:34:50.913549 139996700292992 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0806 09:34:50.929460 139996700292992 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0806 09:34:51.038705 139996700292992 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0806 09:34:51.039596 139996700292992 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
import time
# %cd /content/drive/My Drive/BAM_DIR
start_time = time.time()
# !python -m bam.run_classifier rte-mrpc-bam-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["rte", "mrpc"], "distill": true, "train_batch_size": 64,"learning_rate": 3e-3, "teachers": {"rte": "rte-model", "mrpc": "mrpc-model"}}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# /content/drive/My Drive/BAM_DIR
# WARNING: Logging before flag parsing goes to stderr.
# W0807 05:15:38.349870 140060068984704 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0807 05:15:38.366701 140060068984704 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0807 05:15:38.506373 140060068984704 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0807 05:15:38.507892 140060068984704 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...

# %%
import time
start_time = time.time()
# !python -m bam.run_classifier mrpc-model "/content/drive/My Drive/BAM_DIR" '{"task_names": ["mrpc"],"distill": true,"teachers": {"mrpc": "rte-mrpc-bam-model"}}'
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0807 04:47:26.440121 139781982140288 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/optimization.py:97: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0807 04:47:26.456219 139781982140288 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/helpers/training_utils.py:30: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# W0807 04:47:26.588937 139781982140288 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/run_classifier.py:276: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0807 04:47:26.589956 139781982140288 deprecation_wrapper.py:119] From /content/drive/My Drive/BAM_DIR/bam/bert/tokenization.py:75: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...
